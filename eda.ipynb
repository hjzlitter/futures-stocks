# %%
import pandas as pd

# %%
metal = pd.read_csv("metal.csv")
metal
# Out:
#         Stkcd       Trddt  Opnprc  Hiprc  Loprc  Clsprc   Dnshrtrd  \
# 0         629  2019-04-02    3.72   3.79   3.66    3.75  170463427
# 1         629  2019-04-03    3.83   3.96   3.80    3.81  245673628
# 2         629  2019-04-04    3.79   3.95   3.78    3.86  208801852
# 3         629  2019-04-08    3.91   4.03   3.87    3.99  309676095
# 4         629  2019-04-09    3.95   3.95   3.83    3.86  184560444
# ...       ...         ...     ...    ...    ...     ...        ...
# 51187  688186  2024-03-26   14.08  14.23  13.63   13.88    4665166
# 51188  688186  2024-03-27   13.89  13.95  13.40   13.42    3553653
# 51189  688186  2024-03-28   13.35  13.71  13.31   13.50    3876359
# 51190  688186  2024-03-29   13.55  13.60  13.45   13.58    1971901
# 51191  688186  2024-04-01   13.70  14.14  13.63   14.14    3394275
#
#        Markettype  Trdsta  PreClosePrice  ChangeRatio
# 0               4       1           3.72     0.008065
# ...

# %%
# 使用 zfill 方法将元素填充为指定长度
metal['Stkcd'] = metal['Stkcd'].astype(str).str.zfill(6)

# %%
metal.Stkcd.value_counts()
# Out:
# Stkcd
# 000629    1214
# 002478    1214
# 603878    1214
# 601005    1214
# 601003    1214
# 600808    1214
# 600782    1214
# 600581    1214
# 600569    1214
# 600516    1214
# 600507    1214
# 600307    1214
# 600295    1214
# 600231    1214
# 600019    1214
# 600010    1214
# 600022    1214
# 002443    1214
# 000923    1214
# 002318    1214
# 002110    1214
# 000709    1214
# 000717    1214
# 000778    1214
# 000898    1214
# 000708    1213
# 000761    1213
# 000825    1213
# 000932    1213
# 600117    1213
# 000655    1213
# 600399    1212
# 600382    1211
# 002075    1209
# 600126    1207
# 600282    1205
# 601969    1204
# 000959    1192
# 603995    1035
# 688186    1007
# 300881     868
# 601686     806
# 001203     705
# 301160     445
# 601121     258
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.plot(metal[metal.Stkcd==629].Clsprc)

# %%
coal = pd.read_csv("metal.csv")
coal['Stkcd'] = coal['Stkcd'].astype(str).str.zfill(6)
coal
# Out:
#         Stkcd       Trddt  Opnprc  Hiprc  Loprc  Clsprc   Dnshrtrd  \
# 0      000629  2019-04-02    3.72   3.79   3.66    3.75  170463427
# 1      000629  2019-04-03    3.83   3.96   3.80    3.81  245673628
# 2      000629  2019-04-04    3.79   3.95   3.78    3.86  208801852
# 3      000629  2019-04-08    3.91   4.03   3.87    3.99  309676095
# 4      000629  2019-04-09    3.95   3.95   3.83    3.86  184560444
# ...       ...         ...     ...    ...    ...     ...        ...
# 51187  688186  2024-03-26   14.08  14.23  13.63   13.88    4665166
# 51188  688186  2024-03-27   13.89  13.95  13.40   13.42    3553653
# 51189  688186  2024-03-28   13.35  13.71  13.31   13.50    3876359
# 51190  688186  2024-03-29   13.55  13.60  13.45   13.58    1971901
# 51191  688186  2024-04-01   13.70  14.14  13.63   14.14    3394275
#
#        Markettype  Trdsta  PreClosePrice  ChangeRatio
# 0               4       1           3.72     0.008065
# ...

# %%
nonferrous = pd.read_csv("nonferrous.csv")
nonferrous['Stkcd'] = nonferrous['Stkcd'].astype(str).str.zfill(6)
nonferrous
# Out:
#          Stkcd       Trddt  Opnprc  Hiprc  Loprc  Clsprc   Dnshrtrd  \
# 0       000060  2019-04-02    5.84   6.12   5.65    5.98  345787919
# 1       000060  2019-04-03    5.87   5.98   5.75    5.91  160290468
# 2       000060  2019-04-04    6.10   6.18   5.78    5.90  144774113
# 3       000060  2019-04-08    5.90   6.18   5.82    6.06  165905352
# 4       000060  2019-04-09    5.97   5.97   5.76    5.83   94002352
# ...        ...         ...     ...    ...    ...     ...        ...
# 151966  873576  2024-03-26   22.81  22.99  21.60   21.82     950514
# 151967  873576  2024-03-27   21.83  23.35  21.83   22.06    1044754
# 151968  873576  2024-03-28   22.50  22.60  21.62   22.47     782070
# 151969  873576  2024-03-29   22.47  22.50  21.88   22.08     743548
# 151970  873576  2024-04-01   22.00  22.25  21.88   22.22     720263
#
#         Markettype  Trdsta  PreClosePrice  ChangeRatio
# 0                4       1           5.56     0.075540
# ...

# %%
SH9999 = pd.read_csv("SH9999.XZCE.csv")
SH9999
# Out:
#            date    open    high     low   close    volume         money  \
# 0    2023-09-15  2950.0  3060.0  2790.0  2859.0  407987.0  3.567846e+10
# 1    2023-09-18  2858.0  2922.0  2836.0  2904.0  283416.0  2.452115e+10
# 2    2023-09-19  2913.0  3086.0  2898.0  3040.0  515904.0  4.678733e+10
# 3    2023-09-20  3058.0  3148.0  3038.0  3113.0  598941.0  5.570151e+10
# 4    2023-09-21  3116.0  3118.0  3033.0  3049.0  432914.0  3.985839e+10
# ..          ...     ...     ...     ...     ...       ...           ...
# 124  2024-03-26  2570.0  2597.0  2542.0  2556.0   50111.0  3.863558e+09
# 125  2024-03-27  2558.0  2585.0  2545.0  2555.0   36387.0  2.798888e+09
# 126  2024-03-28  2553.0  2568.0  2473.0  2495.0   80009.0  6.034279e+09
# 127  2024-03-29  2497.0  2504.0  2420.0  2429.0   78383.0  5.775259e+09
# 128  2024-04-01  2420.0  2477.0  2389.0  2475.0   93686.0  6.840952e+09
#
#      open_interest  symbol
# 0          30330.0  SH2405
# 1          32473.0  SH2405
# ...

# %%
# 将给定的股票代码和对应数值转换为Python字典
stocks_dict = {
    "000629": 1214,
    "002478": 1214,
    "603878": 1214,
    "601005": 1214,
    "601003": 1214,
    "600808": 1214,
    "600782": 1214,
    "600581": 1214,
    "600569": 1214,
    "600516": 1214,
    "600507": 1214,
    "600307": 1214,
    "600295": 1214,
    "600231": 1214,
    "600019": 1214,
    "600010": 1214,
    "600022": 1214,
    "002443": 1214,
    "000923": 1214,
    "002318": 1214,
    "002110": 1214,
    "000709": 1214,
    "000717": 1214,
    "000778": 1214,
    "000898": 1214,
    "000708": 1213,
    "000761": 1213,
    "000825": 1213,
    "000932": 1213,
    "600117": 1213,
    "000655": 1213,
    "600399": 1212,
    "600382": 1211,
    "002075": 1209,
    "600126": 1207,
    "600282": 1205,
    "601969": 1204,
    "000959": 1192,
    "603995": 1035,
    "688186": 1007,
    "300881": 868,
    "601686": 806,
    "001203": 705,
    "301160": 445,
    "601121": 258
}

# %%
#stocks_dict['600295'] # SM9999
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [32], line 2
#       1 #stocks_dict['600295'] # SM9999
# ----> 2 stocks_dict['600116']
#
# KeyError: '600116'

# %%
# 热卷主连
# stocks_dict['000761'] # HC9999
# stocks_dict['000825'] # HC9999
# stocks_dict['000708']
# stocks_dict['600117']
# stocks_dict['600507']
# stocks_dict['600399']
# stocks_dict['002318']
# Out:
# 1214

# %%
# RB9999
# stocks_dict['000825']
# stocks_dict['600282']
# stocks_dict['000898']
# stocks_dict['600019']
# stocks_dict['600126']

# %%
# SS9999
# stocks_dict['000761']
# stocks_dict['000932']
# stocks_dict['601005']
# stocks_dict['002478']
# stocks_dict['000825']
# stocks_dict['000708']
# stocks_dict['600307']
# stocks_dict['000898']
# stocks_dict['600117']
# stocks_dict['000778']
# stocks_dict['600507']
# stocks_dict['000709']
# stocks_dict['000717']
# stocks_dict['688186']
# stocks_dict['300881']
# stocks_dict['600399']
# stocks_dict['002318']
# stocks_dict['600126']
# stocks_dict['603315']
# stocks_dict['002075']

# %%
def judge(x):
    if (metal.Stkcd == str(x)).sum() > 0:
        return "metal"
    elif (coal.Stkcd == str(x)).sum() > 0:
        return "coal"
    elif (nonferrous.Stkcd == str(x)).sum() > 0: 
        return "nonferrous"

# %%
# 601899 600362 000630 601168 000878
judge('000878')
# Out:
# 'nonferrous'
